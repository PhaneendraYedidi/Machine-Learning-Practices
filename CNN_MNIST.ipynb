# %%
# Credits: https://github.com/keras-team/keras/blob/master/examples/mnist_cnn.py


from __future__ import print_function
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K

batch_size = 128
num_classes = 10
epochs = 12

# input image dimensions
img_rows, img_cols = 28, 28

# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()

if K.image_data_format() == 'channels_first':
    x_train = x_train.reshape(x_train.shape[0], 1, img_rows, img_cols)
    x_test = x_test.reshape(x_test.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
    x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
    input_shape = (img_rows, img_cols, 1)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=input_shape))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])

model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples
# Epoch 1/12
# 469/469 [==============================] - 4s 8ms/step - loss: 2.2708 - accuracy: 0.1481 - val_loss: 2.2255 - val_accuracy: 0.2959
# Epoch 2/12
# 469/469 [==============================] - 4s 8ms/step - loss: 2.1996 - accuracy: 0.2589 - val_loss: 2.1386 - val_accuracy: 0.4399
# Epoch 3/12
# 469/469 [==============================] - 4s 8ms/step - loss: 2.1113 - accuracy: 0.3537 - val_loss: 2.0253 - val_accuracy: 0.5975
# Epoch 4/12
# 469/469 [==============================] - 4s 8ms/step - loss: 1.9921 - accuracy: 0.4514 - val_loss: 1.8731 - val_accuracy: 0.7195
# Epoch 5/12
# 469/469 [==============================] - 4s 8ms/step - loss: 1.8447 - accuracy: 0.5286 - val_loss: 1.6853 - val_accuracy: 0.7696
# Epoch 6/12
# 469/469 [==============================] - 4s 8ms/step - loss: 1.6697 - accuracy: 0.5860 - val_loss: 1.4749 - val_accuracy: 0.7890
# Epoch 7/12
# 469/469 [==============================] - 4s 8ms/step - loss: 1.4930 - accuracy: 0.6254 - val_loss: 1.2683 - val_accuracy: 0.8003
# Epoch 8/12
# 469/469 [==============================] - 4s 8ms/step - loss: 1.3358 - accuracy: 0.6501 - val_loss: 1.0898 - val_accuracy: 0.8116
# Epoch 9/12
# 469/469 [==============================] - 4s 8ms/step - loss: 1.2023 - accuracy: 0.6737 - val_loss: 0.9470 - val_accuracy: 0.8217
# Epoch 10/12
# 469/469 [==============================] - 4s 8ms/step - loss: 1.0961 - accuracy: 0.6933 - val_loss: 0.8369 - val_accuracy: 0.8301
# Epoch 11/12
# 469/469 [==============================] - 4s 8ms/step - loss: 1.0078 - accuracy: 0.7121 - val_loss: 0.7511 - val_accuracy: 0.8400
# Epoch 12/12
# 469/469 [==============================] - 4s 8ms/step - loss: 0.9434 - accuracy: 0.7252 - val_loss: 0.6853 - val_accuracy: 0.8474
# Test loss: 0.6853204965591431
# Test accuracy: 0.8474000096321106

# %%
# Credits: https://github.com/keras-team/keras/blob/master/examples/mnist_cnn.py


from __future__ import print_function
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K
import matplotlib.pyplot as plt
from keras.layers.normalization import BatchNormalization

# %% [markdown]
# ## Model 1: 3 Convolution Layers

# %%
batch_size = 128
num_classes = 10
epochs = 12

# input image dimensions
img_rows, img_cols = 28, 28

# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()

if K.image_data_format() == 'channels_first':
    x_train = x_train.reshape(x_train.shape[0], 1, img_rows, img_cols)
    x_test = x_test.reshape(x_test.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
    x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
    input_shape = (img_rows, img_cols, 1)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

model = Sequential()
model.add(Conv2D(128, kernel_size=(5, 5),
                 activation='relu',
                 input_shape=input_shape))
model.add(Conv2D(128, (5, 5), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, (5, 5), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])


fig,ax = plt.subplots(1,1)
ax.set_xlabel('epoch') ; ax.set_ylabel('Categorical Crossentropy Loss')

# list of epoch numbers
x = list(range(1,epochs+1))

def plt_dynamic(x, vy, ty, ax, colors=['b']):
    ax.plot(x, vy, 'b', label="Validation Loss")
    ax.plot(x, ty, 'r', label="Train Loss")
    plt.legend()
    plt.grid()
    fig.canvas.draw()

vy = history.history['val_loss']
ty = history.history['loss']
plt_dynamic(x, vy, ty, ax)
# Out:
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples
# Epoch 1/12
# 469/469 [==============================] - 10s 22ms/step - loss: 3.3110 - accuracy: 0.2342 - val_loss: 1.5925 - val_accuracy: 0.5559
# Epoch 2/12
# 469/469 [==============================] - 10s 21ms/step - loss: 1.8621 - accuracy: 0.4484 - val_loss: 0.6255 - val_accuracy: 0.8228
# Epoch 3/12
# 469/469 [==============================] - 10s 22ms/step - loss: 1.3404 - accuracy: 0.5774 - val_loss: 0.4575 - val_accuracy: 0.8701
# Epoch 4/12
# 469/469 [==============================] - 10s 21ms/step - loss: 1.0756 - accuracy: 0.6561 - val_loss: 0.3698 - val_accuracy: 0.8967
# Epoch 5/12
# 469/469 [==============================] - 10s 21ms/step - loss: 0.9111 - accuracy: 0.7073 - val_loss: 0.3170 - val_accuracy: 0.9141
# Epoch 6/12
# 469/469 [==============================] - 10s 21ms/step - loss: 0.7948 - accuracy: 0.7429 - val_loss: 0.2801 - val_accuracy: 0.9239
# Epoch 7/12
# 469/469 [==============================] - 10s 21ms/step - loss: 0.7072 - accuracy: 0.7734 - val_loss: 0.2523 - val_accuracy: 0.9298
# Epoch 8/12
# 469/469 [==============================] - 10s 21ms/step - loss: 0.6488 - accuracy: 0.7903 - val_loss: 0.2302 - val_accuracy: 0.9362
# Epoch 9/12
# 469/469 [==============================] - 10s 21ms/step - loss: 0.5908 - accuracy: 0.8118 - val_loss: 0.2134 - val_accuracy: 0.9402
# Epoch 10/12
# 469/469 [==============================] - 10s 21ms/step - loss: 0.5524 - accuracy: 0.8245 - val_loss: 0.1992 - val_accuracy: 0.9431
# Epoch 11/12
# 469/469 [==============================] - 10s 21ms/step - loss: 0.5126 - accuracy: 0.8364 - val_loss: 0.1869 - val_accuracy: 0.9460
# Epoch 12/12
# 469/469 [==============================] - 10s 21ms/step - loss: 0.4868 - accuracy: 0.8451 - val_loss: 0.1760 - val_accuracy: 0.9491
# Test loss: 0.17600411176681519
# Test accuracy: 0.9490000009536743

# %% [markdown]
# ##Model 2: 5 Convolution Layers

# %%
batch_size = 128
num_classes = 10
epochs = 12

# input image dimensions
img_rows, img_cols = 28, 28

# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()

if K.image_data_format() == 'channels_first':
    x_train = x_train.reshape(x_train.shape[0], 1, img_rows, img_cols)
    x_test = x_test.reshape(x_test.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
    x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
    input_shape = (img_rows, img_cols, 1)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

model = Sequential()
model.add(Conv2D(64, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=input_shape))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])


fig,ax = plt.subplots(1,1)
ax.set_xlabel('epoch') ; ax.set_ylabel('Categorical Crossentropy Loss')

# list of epoch numbers
x = list(range(1,epochs+1))

def plt_dynamic(x, vy, ty, ax, colors=['b']):
    ax.plot(x, vy, 'b', label="Validation Loss")
    ax.plot(x, ty, 'r', label="Train Loss")
    plt.legend()
    plt.grid()
    fig.canvas.draw()

vy = history.history['val_loss']
ty = history.history['loss']
plt_dynamic(x, vy, ty, ax)
# Out:
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples
# Epoch 1/12
# 469/469 [==============================] - 7s 15ms/step - loss: 3.6901 - accuracy: 0.1684 - val_loss: 2.2417 - val_accuracy: 0.1628
# Epoch 2/12
# 469/469 [==============================] - 7s 14ms/step - loss: 2.5282 - accuracy: 0.2973 - val_loss: 1.2399 - val_accuracy: 0.6283
# Epoch 3/12
# 469/469 [==============================] - 7s 14ms/step - loss: 1.9888 - accuracy: 0.3966 - val_loss: 0.9520 - val_accuracy: 0.7306
# Epoch 4/12
# 469/469 [==============================] - 7s 14ms/step - loss: 1.6498 - accuracy: 0.4796 - val_loss: 0.7806 - val_accuracy: 0.7906
# Epoch 5/12
# 469/469 [==============================] - 7s 14ms/step - loss: 1.4157 - accuracy: 0.5470 - val_loss: 0.6609 - val_accuracy: 0.8264
# Epoch 6/12
# 469/469 [==============================] - 6s 14ms/step - loss: 1.2507 - accuracy: 0.5943 - val_loss: 0.5710 - val_accuracy: 0.8503
# Epoch 7/12
# 469/469 [==============================] - 6s 14ms/step - loss: 1.1175 - accuracy: 0.6391 - val_loss: 0.5038 - val_accuracy: 0.8675
# Epoch 8/12
# 469/469 [==============================] - 6s 14ms/step - loss: 1.0118 - accuracy: 0.6716 - val_loss: 0.4495 - val_accuracy: 0.8822
# Epoch 9/12
# 469/469 [==============================] - 6s 14ms/step - loss: 0.9249 - accuracy: 0.7008 - val_loss: 0.4046 - val_accuracy: 0.8928
# Epoch 10/12
# 469/469 [==============================] - 6s 14ms/step - loss: 0.8589 - accuracy: 0.7231 - val_loss: 0.3676 - val_accuracy: 0.9008
# Epoch 11/12
# 469/469 [==============================] - 6s 14ms/step - loss: 0.7885 - accuracy: 0.7480 - val_loss: 0.3376 - val_accuracy: 0.9084
# Epoch 12/12
# 469/469 [==============================] - 6s 14ms/step - loss: 0.7417 - accuracy: 0.7616 - val_loss: 0.3130 - val_accuracy: 0.9138
# Test loss: 0.3129693269729614
# Test accuracy: 0.9138000011444092

# %% [markdown]
# ## Model 3: 7 Convolution Layers

# %%
batch_size = 128
num_classes = 10
epochs = 12

# input image dimensions
img_rows, img_cols = 28, 28

# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()

if K.image_data_format() == 'channels_first':
    x_train = x_train.reshape(x_train.shape[0], 1, img_rows, img_cols)
    x_test = x_test.reshape(x_test.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
    x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
    input_shape = (img_rows, img_cols, 1)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

model = Sequential()

model.add(Conv2D(128, kernel_size=(2, 2),
                 activation='relu',
                 input_shape=input_shape))
model.add(Conv2D(128, (2, 2), activation='relu'))
model.add(Conv2D(128, (2, 2), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))

#model.add(Conv2D(128, kernel_size=(2, 2), activation='relu'))
#model.add(Conv2D(128, (2, 2), activation='relu'))
#model.add(BatchNormalization())
#model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, kernel_size=(2, 2), activation='relu'))
model.add(Conv2D(128, (2, 2), activation='relu'))
model.add(Conv2D(128, (2, 2), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])


fig,ax = plt.subplots(1,1)
ax.set_xlabel('epoch') ; ax.set_ylabel('Categorical Crossentropy Loss')

# list of epoch numbers
x = list(range(1,epochs+1))

def plt_dynamic(x, vy, ty, ax, colors=['b']):
    ax.plot(x, vy, 'b', label="Validation Loss")
    ax.plot(x, ty, 'r', label="Train Loss")
    plt.legend()
    plt.grid()
    fig.canvas.draw()

vy = history.history['val_loss']
ty = history.history['loss']
plt_dynamic(x, vy, ty, ax)
# Out:
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples
# Epoch 1/12
#   2/469 [..............................] - ETA: 18s - loss: 2.4846 - accuracy: 0.1172WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0202s vs `on_train_batch_end` time: 0.0309s). Check your callbacks.
# 469/469 [==============================] - 16s 33ms/step - loss: 2.3419 - accuracy: 0.1230 - val_loss: 2.2568 - val_accuracy: 0.3330
# Epoch 2/12
# 469/469 [==============================] - 16s 34ms/step - loss: 2.1885 - accuracy: 0.2104 - val_loss: 2.0467 - val_accuracy: 0.5948
# Epoch 3/12
# 469/469 [==============================] - 16s 33ms/step - loss: 2.0515 - accuracy: 0.3122 - val_loss: 1.8497 - val_accuracy: 0.7111
# Epoch 4/12
# 469/469 [==============================] - 15s 33ms/step - loss: 1.8874 - accuracy: 0.3964 - val_loss: 1.6094 - val_accuracy: 0.7624
# Epoch 5/12
# 469/469 [==============================] - 15s 33ms/step - loss: 1.7045 - accuracy: 0.4672 - val_loss: 1.3513 - val_accuracy: 0.7959
# Epoch 6/12
# 469/469 [==============================] - 15s 33ms/step - loss: 1.5185 - accuracy: 0.5275 - val_loss: 1.1139 - val_accuracy: 0.8266
# Epoch 7/12
# 469/469 [==============================] - 16s 33ms/step - loss: 1.3530 - accuracy: 0.5782 - val_loss: 0.9182 - val_accuracy: 0.8490
# Epoch 8/12
# 469/469 [==============================] - 16s 33ms/step - loss: 1.2072 - accuracy: 0.6219 - val_loss: 0.7689 - val_accuracy: 0.8692
# Epoch 9/12
# 469/469 [==============================] - 16s 33ms/step - loss: 1.0931 - accuracy: 0.6554 - val_loss: 0.6536 - val_accuracy: 0.8831
# Epoch 10/12
# 469/469 [==============================] - 15s 33ms/step - loss: 0.9972 - accuracy: 0.6845 - val_loss: 0.5654 - val_accuracy: 0.8925
# Epoch 11/12
# 469/469 [==============================] - 15s 33ms/step - loss: 0.9145 - accuracy: 0.7107 - val_loss: 0.4968 - val_accuracy: 0.9029
# Epoch 12/12
# 469/469 [==============================] - 15s 33ms/step - loss: 0.8368 - accuracy: 0.7350 - val_loss: 0.4411 - val_accuracy: 0.9096
# Test loss: 0.441052109003067
# Test accuracy: 0.909600019454956

# %% [markdown]
# ##Conclusion

# %%
# Please compare all your models using Prettytable library
# !pip install PTable

from prettytable import PrettyTable
    
x = PrettyTable()

x.field_names = ["Layers", "Test loss","Test Accuracy"]

x.add_row(["3 Convolution Layers ",0.1760, 0.9490])
x.add_row(["5 Convolution Layers", 0.3129,0.9138])
x.add_row(["7 Convolution Layers", 0.4410,0.9096])


print(x)
# Out:
# Collecting PTable
#   Downloading https://files.pythonhosted.org/packages/ab/b3/b54301811173ca94119eb474634f120a49cd370f257d1aae5a4abaf12729/PTable-0.9.2.tar.gz
# Building wheels for collected packages: PTable
#   Building wheel for PTable (setup.py) ... done
#   Created wheel for PTable: filename=PTable-0.9.2-cp36-none-any.whl size=22905 sha256=9220094ee4b9e133eba57d9265c95be4c99dcda9bb339c540d21d887680b9059
#   Stored in directory: /root/.cache/pip/wheels/22/cc/2e/55980bfe86393df3e9896146a01f6802978d09d7ebcba5ea56
# Successfully built PTable
# Installing collected packages: PTable
# Successfully installed PTable-0.9.2
# +-----------------------+-----------+---------------+
# |         Layers        | Test loss | Test Accuracy |
# +-----------------------+-----------+---------------+
# | 3 Convolution Layers  |   0.176   |     0.949     |
# |  5 Convolution Layers |   0.3129  |     0.9138    |
# |  7 Convolution Layers |   0.441   |     0.9096    |
# +-----------------------+-----------+---------------+

# %% [markdown]
# ##Further Reading

# %% [markdown]
# **Convolution**
# A convolution is the simple application of a filter to an input that results in an activation. Repeated application of the same filter to an input results in a map of activations called a feature map, indicating the locations and strength of a detected feature in an input, such as an image.
# Ref:https://machinelearningmastery.com/convolutional-layers-for-deep-learning-neural-networks/
#
# **MaxPooling**:
#
# A pooling layer is another building block of a CNN. Its function is to progressively reduce the spatial size of the representation to reduce the amount of parameters and computation in the network. Pooling layer operates on each feature map independently. The most common approach used in pooling is max pooling.
#
#
# **Dense Layer:**
#
# A dense layer represents a matrix vector multiplication. (assuming your batch size is 1) The values in the matrix are the trainable parameters which get updated during backpropagation.
#
# uT.W,W∈Rn×m
#
# So you get a m dimensional vector as output. A dense layer thus is used to change the dimensions of your vector. Mathematically speaking, it applies a rotation, scaling, translation transform to your vector.
#
# **Dropout Layer:**
#
# Dropout is a regularization technique, which aims to reduce the complexity of the model with the goal to prevent overfitting.
#
# Using “dropout", you randomly deactivate certain units (neurons) in a layer with a certain probability p from a Bernoulli distribution (typically 50%, but this yet another hyperparameter to be tuned). So, if you set half of the activations of a layer to zero, the neural network won’t be able to rely on particular activations in a given feed-forward pass during training. As a consequence, the neural network will learn different, redundant representations; the network can’t rely on the particular neurons and the combination (or interaction) of these to be present. Another nice side effect is that training will be faster.
#
# Additional technical notes: Dropout is only applied during training, and you need to rescale the remaining neuron activations. E.g., if you set 50% of the activations in a given layer to zero, you need to scale up the remaining ones by a factor of 2. Finally, if the training has finished, you’d use the complete network for testing (or in other words, you set the dropout probability to 0).
#
# For more details, I recommend the original paper: Srivastava, N., Hinton, G., Krizhevsky, A., Sutskever, I., & Salakhutdinov, R. (2014). Dropout: A simple way to prevent neural networks from overfitting. The Journal of Machine Learning Research, 15(1), 1929-1958.
#
# Additional info: A dropout layer is used for regularization where you randomly set some of the dimensions of your input vector to be zero with probability  keep_prob . A dropout layer does not have any trainable parameters i.e. nothing gets updated during backward pass of backpropagation. To ensure that expected sum of vectors fed to this layer remains the same if no dropout was applied, the remaining dimensions which are not set to zero are scaled by  1keep_prob
#
# Ref : https://www.quora.com/In-Keras-what-is-a-dense-and-a-dropout-layer
#
#
# **Flatten**
#
# 2D convolution layers processing 2D data (for example, images) usually output a tridimensional tensor, with the dimensions being the image resolution (minus the filter size -1) and the number of filters. If you use a layer with N filters of size s on WxH images, the result will be of dimension (W-(s-1), H - (s-1), N). You have N images of resolution (W-(s-1), H - (s-1)). This structure is important if you want to chain convolution layers together or with other layers that perform a spatial treatment (pooling, upscaling, etc.).
#
# But if you want to do classification, in the last steps of your network, you usually want to use fully connected layers that don’t take any structure (spatial or otherwise) into account for processing, so you just want the output of the last convolution layers to be considered as a large piece of unstructured data.
#
# That’s what “flattening” means. It breaks the spatial structure of the data and transforms your tridimensional (W-(s-1), H - (s-1), N) tensor into a monodimensional tensor (a vector) of size (W-(s-1))x(H - (s-1))xN.
#
# Addition info: Flatten layers allow you to change the shape of the data from a vector of 2d matrixes (or nd matrices really) into the correct format for a dense layer to interpret. It’s simply allowing the data to be operable by this different layer type.
#
# **Note**
# When to use drop outs and Batch Normalization:
# https://www.kdnuggets.com/2018/09/dropout-convolutional-networks.html
